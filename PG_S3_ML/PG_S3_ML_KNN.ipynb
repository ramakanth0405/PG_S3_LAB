# %% [markdown]
# # K Nearest Neighbours

# %% [markdown]
# 21 July 2026, Tuesday

# %% [markdown]
# ## 1. Importing Libraries

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from scipy.stats import mode

# %% [markdown]
# ## 2. Load dataset

# %%
df = pd.read_csv("../Datasets/diabetes.csv")
X = df.iloc[:, :-1].values
Y = df.iloc[:, -1].values

# %% [markdown]
# ## 3. Split dataset into train and test sets

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=1/3, random_state=0
)

# %% [markdown]
# ## 4. KNN Model

# %%
model1 = KNeighborsClassifier(n_neighbors=K)
model1.fit(X_train, Y_train)
Y_pred1 = model1.predict(X_test)

# %% [markdown]
# ## 5. Measure performance

# %%
correctly_classified = np.sum(Y_test.ravel() == Y_predict.ravel())
correctly_classified1 = np.sum(Y_test.ravel() == Y_pred1.ravel())
total_samples = len(Y_test)
print("Accuracy on test set by model :", (correctly_classified1 / total_samples) * 100)
# Out:
# Accuracy on test set by model : 69.53125

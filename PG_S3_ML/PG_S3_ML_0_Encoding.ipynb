# %% [markdown]
# 10 JUNE 2026 WEDNESDAY

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
data = ['Red', 'Blue', 'Green', 'Blue']

# %%
le = LabelEncoder()
encoded_data = le.fit_transform(data)
print('Encoded Data:\n', encoded_data)
# Out:
# Encoded Data:
#  [2 0 1 0]

# %% [markdown]
# One-Hot Encoding

# %%
from sklearn.preprocessing import OneHotEncoder
import pandas as pd

# %%
data = pd.DataFrame({'Fruits': ['Apple', 'Mango', 'Banana', 'Mango', 'Orange', 'Apple']}, columns = ['Fruits'])

# %%
data
# Out:
#    Fruits
# 0   Apple
# 1   Mango
# 2  Banana
# 3   Mango
# 4  Orange
# 5   Apple

# %%
one_hot_encoded = pd.get_dummies(data['Fruits'])

# %%
one_hot_encoded
# Out:
#    Apple  Banana  Mango  Orange
# 0   True   False  False   False
# 1  False   False   True   False
# 2  False    True  False   False
# 3  False   False   True   False
# 4  False   False  False    True
# 5   True   False  False   False

# %% [markdown]
# Ordinal Encoding

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
data = {'Grade':['High', 'Medium', 'Low', 'High']}
df = pd.DataFrame(data)
print(df)
# Out:
#     Grade
# 0    High
# 1  Medium
# 2     Low
# 3    High

# %%
encoder_ord = OrdinalEncoder(categories = [['Low', 'Medium', 'High']]) # Use [[]]
encoded_data = encoder_ord.fit_transform(df[['Grade']])
print(encoded_data)
# Out:
# [[2.]
#  [1.]
#  [0.]
#  [2.]]

# %%
type(encoded_data)
# Out:
# numpy.ndarray

# %%
for i in encoded_data:
  if i == [0.]:
    print(i, 'Low')
  elif i ==[1.]:
    print(i, 'Medium')
  else:
    print(i, 'High')
# Out:
# [2.] High
# [1.] Medium
# [0.] Low
# [2.] High

# %% [markdown]
# Target Encoding

# %%
import category_encoders as ce

# %%
df = pd.DataFrame(
    {'City': ['London', 'Paris', 'London', 'Berlin'], 
     'Target': [1, 0, 1, 0]}
)

# %%
encoder_target = ce.TargetEncoder(cols = ['City'])
df_tgt = encoder_target.fit_transform(df['City'], df['Target'])
df_tgt
# Out:
#        City
# 0  0.570926
# 1  0.434946
# 2  0.570926
# 3  0.434946

# %% [markdown]
# Binary Encoder

# %%
import category_encoders as ce

# %%
data_bin = ['Red', 'Green', 'Blue', 'Red']
encoder_bin = ce.BinaryEncoder(cols = ['Color'])
encoder_data = encoder_bin.fit_transform(pd.DataFrame(data_bin, columns = ['Color']))
encoder_data
# Out:
#    Color_0  Color_1
# 0        0        1
# 1        1        0
# 2        1        1
# 3        0        1

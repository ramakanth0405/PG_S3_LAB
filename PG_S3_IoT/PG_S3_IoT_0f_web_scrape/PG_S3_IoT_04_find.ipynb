# %% [markdown]
# Difference between find and find all

# %% [markdown]
# 24 June 2026 Wednesday

# %%
from bs4 import BeautifulSoup
import requests
filepath = '/Users/ramakanthvprabhu/Desktop/PG_S3/PG_S3_IoT/PG_S3_IoT_0f_web_scrape/IoT_Webscrape_local/parse.html'

# %%
with open(filepath, 'r', encoding='utf-8') as f:
    html_content = f.read()

# %%
soup = BeautifulSoup(html_content, 'html.parser')

# %% [markdown]
# find

# %%
soup.find('p')
# Out:
# <p class="info">This is a shopping website.</p>

# %%
tag = soup.find('p', class_ = 'info')
print(tag)
# Out:
# <p class="info">This is a shopping website.</p>

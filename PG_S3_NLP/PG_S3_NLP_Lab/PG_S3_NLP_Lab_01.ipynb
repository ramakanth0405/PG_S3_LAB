# %% [markdown]
# 17 June 2026 Wednesday

# %% [markdown]
# Tokenization and PoS Tagging using NLTK

# %% [markdown]
# # AIM
# # Write a python program to perform word tokenization, sentence tokenization and Part of Speech  (PoS Tagging using NLTK)

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/ramakanthvprabhu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/ramakanthvprabhu/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %% [markdown]
# ## Tokenization

# %% [markdown]
# ### Sentence Tokenization

# %%
from nltk.tokenize import sent_tokenize
text = input('Enter Sentence to be Sentence Tokenized')
sentences = sent_tokenize(text)
print(sentences)
# Out:
# ['Hello This is sam.', 'How are you doing?']

# %% [markdown]
# ### Word Tokenization

# %%
from nltk.tokenize import word_tokenize
text = input('Enter Text to be Word Tokenized: ')
words = word_tokenize(text)
print(words)
# Out:
# ['Hello', 'this', 'is', 'Sam', '.', 'How', 'are', 'you', 'doing', '?']

# %% [markdown]
# ## Part of Speech (PoS) Tagging

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
nltk.download('averaged_perceptron_tagger_eng')

# %%
stop_words = set(stopwords.words('english'))
text = ('English texts for beginners to practice reading and comprehension online and for free. Practicing your comprehension of written English will both improve your vocabulary and understanding of grammar and word order. The texts below are designed to help you develop while giving you an instant evaluation of your progress.')

# %% [markdown]
# Sentence Tokenization

# %%
tokenized = sent_tokenize(text)
print(tokenized)
# Out:
# ['English texts for beginners to practice reading and comprehension online and for free.', 'Practicing your comprehension of written English will both improve your vocabulary and understanding of grammar and word order.', 'The texts below are designed to help you develop while giving you an instant evaluation of your progress.']

# %% [markdown]
# Word Tokenization

# %%
for sentence in tokenized:
    words = word_tokenize(sentence)
    words = [w for w in words if w.lower() not in stop_words]
    tagged = nltk.pos_tag(words)

# %%
words
# Out:
# ['texts',
#  'designed',
#  'help',
#  'develop',
#  'giving',
#  'instant',
#  'evaluation',
#  'progress',
#  '.']

# %%
tagged
# Out:
# [('texts', 'NN'),
#  ('designed', 'VBN'),
#  ('help', 'NN'),
#  ('develop', 'VB'),
#  ('giving', 'VBG'),
#  ('instant', 'JJ'),
#  ('evaluation', 'NN'),
#  ('progress', 'NN'),
#  ('.', '.')]

# %% [markdown]
# Common PoS (Part of Speech tag)
#
# - CC - Conjunction
# - CD - Number
# - DT - Determiner
# - EX - Existential
# - FW - Foreign word
# - IN -Preposition
# - JJ / JJR / JJS - Adjective / Comparative / Superlative
# - NN / NNS / NNP / NNPS - Noun singular/plural / Proper noun
# - PRP / PRP$ - Pronoun / Possessive pronoun
# - RB / RBR / RBS - Adverb / Comparative / Superlative
# - VB / VBD / VBG / VBN / VBP / VBZ - Verb forms
# - MD - Modal
# - POS - Possessive ending
# - RP - Particle
# - TO - To
# - UH - Interjection
# - WDT / WP / WP$ / WRB - Wh-determiners/pronouns/adverb

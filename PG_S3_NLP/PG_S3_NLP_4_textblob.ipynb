# %% [markdown]
# # Write a Python program to perform Part of Speech (PoS) tagging using textblob

# %% [markdown]
# 10 June 2026 Wednesday

# %%
from textblob import TextBlob

# %% [markdown]
# python -m textblob.download_corpora

# %%
text = 'This is Amazon services calling you to inform you about out latest service'

# %%
blob_object = TextBlob(text)

# %%
blob_object
# Out:
# TextBlob("This is Amazon services calling you to inform you about out latest service")

# %%
blob_object.tags
# Out:
# [('This', 'DT'),
#  ('is', 'VBZ'),
#  ('Amazon', 'NNP'),
#  ('services', 'NNS'),
#  ('calling', 'VBG'),
#  ('you', 'PRP'),
#  ('to', 'TO'),
#  ('inform', 'VB'),
#  ('you', 'PRP'),
#  ('about', 'IN'),
#  ('out', 'RP'),
#  ('latest', 'JJS'),
#  ('service', 'NN')]

# %% [markdown]
# The output is similar to NLTK output as textblob is built on nltk.
